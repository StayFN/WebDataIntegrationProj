# %%
import pandas as pd
#Load DBPedia_Companies_Preprocessed.csv with pandas
df = pd.read_csv(r'../Data/DBPedia_Companies_Preprocessed.csv', sep=',', encoding='utf-8', index_col=0)
df.head()
# Out:
#                                                      company  \
# DBPedia_0               http://dbpedia.org/resource/BioNTech
# DBPedia_1         http://dbpedia.org/resource/Royal_Ceramics
# DBPedia_2  http://dbpedia.org/resource/Vodafone_Kabel_Deu...
# DBPedia_3  http://dbpedia.org/resource/Union_Pacific_Corp...
# DBPedia_4           http://dbpedia.org/resource/Vallibel_One
#
#                                 label              industries  \
# DBPedia_0                    BioNTech           Biotechnology
# DBPedia_1              Royal Ceramics            Capital good
# DBPedia_2  Vodafone Kabel Deutschland       Telecommunication
# DBPedia_3   Union Pacific Corporation                     NaN
# DBPedia_4                Vallibel One  Conglomerate (company)
#
#                                                    keyPeople  \
# DBPedia_0  Ryan Richardson, Sean Marett, Sierk Poetting, ...
# DBPedia_1  A. M. Weerasinghe, Aravinda Perera, H. Amarase...
# ...

# %%
problematic_df = df[df['revenue'].astype(str).str.contains('"')]

problematic_df.head()
# Out:
#                                                         company  \
# DBPedia_2544                http://dbpedia.org/resource/Enea_SA
# DBPedia_3040         http://dbpedia.org/resource/Manitoba_Hydro
# DBPedia_3168          http://dbpedia.org/resource/Orange_Polska
# DBPedia_3421     http://dbpedia.org/resource/Saur_Neptun_Gdańsk
# DBPedia_4625  http://dbpedia.org/resource/Zakłady_Azotowe_Pu...
#
#                                label  \
# DBPedia_2544                 Enea SA
# DBPedia_3040          Manitoba Hydro
# DBPedia_3168           Orange Polska
# DBPedia_3421      Saur Neptun Gdańsk
# DBPedia_4625  Zakłady Azotowe Puławy
#
#                                                      industries  \
# DBPedia_2544                                    Energy industry
# DBPedia_3040  Electric power distribution, Electric power tr...
# DBPedia_3168                                  Telecommunication
# DBPedia_3421                                     Water industry
# ...
